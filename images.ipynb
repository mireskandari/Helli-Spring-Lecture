# %% [markdown]
# ### Architectures
# <img src="images\gen.png">

# %% [markdown]
# ### Autoencoders Examples
# <img src="images\map_ae.webp">
# <br>
# <img src="images\ae_apps.png">
# <br>
# <img src="images\ae_schema.jpg">

# %% [markdown]
# ### GAN
# <img src="images\gan_schema.png">
# <br>
# <img src="images\gan2.png">

# %% [markdown]
# ### Diffusion Models
#
# <img src="images\diff_vis.jpeg">
# <br>
# <img src="images\diff2.png">
# <br>
# <img src="images\diff1.webp">
